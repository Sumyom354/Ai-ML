# %% [markdown]
# <h1 align="center">Practice Problems 2 </h1>

# %% [markdown]
# <h3>1. Read the dataset to python environment. </h3>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes_model=pd.read_csv('diabetes.csv')

# %%
diabetes_model
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# <h3>2. Display the columns in the dataset.</h3>

# %%
diabetes_model.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# <h3>3. Calculate the mean of each column of the dataset.</h3>

# %%
diabetes_model.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %% [markdown]
# <h3>4. Check for the null values present in the dataset. </h3>

# %%
#checking null values present in the dataset
diabetes_model.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
#Total number of null values in the dataset
diabetes_model.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# <h3>5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations. </h3>

# %%
#general information abount dataframe
diabetes_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# <h4>Histogram</h4>

# %%
#Create a histogram of 'Age' distribution
plt.figure(figsize=(5,5))
plt.hist(diabetes_model['Age'],color='green',edgecolor='red')
plt.title('Age distribution',fontsize=12)
plt.xlabel('Age of Patients')
plt.ylabel('Freequency of Patients')
# Out:
# Text(0, 0.5, 'Freequency of Patients')

# %% [markdown]
# <h4>Heatmap</h4>

# %%
#Create a heatmap
# Calculate the correlation matrix
correlation_matrix = diabetes_model.corr()
# Plot the heatmap
plt.figure(figsize=(8,8))
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# <h4>Boxplot</h4>

# %%
#convert numerical 'Outcome' to categorical 'Outcome'
diabetes_model['Outcome']=diabetes_model['Outcome'].astype('category')

# %%
diabetes_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    category
# dtypes: category(1), float64(2), int64(6)
# memory usage: 49.0 KB

# %%
# Boxplot for 'Glucose' vs 'Outcome'
plt.figure(figsize=(5,5))
sns.boxplot(x='Outcome', y='Glucose', data=diabetes_model,palette='coolwarm')
plt.title('Glucose Levels vs Outcome')
plt.xlabel('Diabetes Outcome (0: No Diabetes, 1: Diabetes)')
plt.ylabel('Glucose Level')
plt.show()
